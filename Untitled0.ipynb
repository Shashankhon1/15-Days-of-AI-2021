# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashankhon1/15-Days-of-AI-2021/blob/Shashank-H-S/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=range(10)
y=range(10)
x1=range(11,21)
y2=range(11,21)
plt.plot(x,y,color="green")
plt.plot(x1,y2)
plt.show()
